# %% [markdown]
# <a href="https://colab.research.google.com/github/XavierCarrera/Datascience/blob/main/Inmuebles_Peru_RegresionLineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv("/content/drive/MyDrive/inmuebles_datasets/inmuebles_peru.csv")
df
# Out:
#        Unnamed: 0  rooms  ...  property_type_Oficina  property_type_PH
# 0               0    3.0  ...                      0                 0
# 1               1    4.0  ...                      0                 0
# 2               2    3.0  ...                      0                 0
# 3               3    3.0  ...                      0                 0
# 4               4    5.0  ...                      0                 0
# ...           ...    ...  ...                    ...               ...
# 78263      124442    9.0  ...                      0                 0
# 78264      124444   13.0  ...                      0                 0
# 78265      124445   13.0  ...                      1                 0
# 78266      124446   13.0  ...                      0                 0
# 78267      124447   12.0  ...                      0                 0
#
# [78268 rows x 167 columns]
